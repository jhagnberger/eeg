# %%
import mne
import sys
import numpy as np
from matplotlib import pyplot as plt

# %%
# Load the data
from mne_bids import (BIDSPath,read_raw_bids)

# path where to save the datasets.
bids_root = "/Users/jan/Documents/git/ds003846"
subject_id = '02' # recommend subject 30 for now


bids_path = BIDSPath(subject=subject_id, task="PredictionError", session="EMS",
                     datatype='eeg', suffix='eeg',
                     root=bids_root)

# read the file
raw = read_raw_bids(bids_path)
raw.info
# Out:
# Extracting parameters from /Users/jan/Documents/git/ds003846/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_eeg.vhdr...
# Setting channel info structure...
# Reading events from /Users/jan/Documents/git/ds003846/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_events.tsv.
# Reading channel info from /Users/jan/Documents/git/ds003846/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_channels.tsv.
# /var/folders/bb/xxm_9vsj1w9c1jg8lvn4kll00000gn/T/ipykernel_61359/2848144100.py:14: RuntimeWarning: Unable to map the following column(s) to to MNE:
# cap_size: 58
# block_1: Visual
# block_2: Visual + Vibro
# block_3: Visual + Vibro + EMS
#   raw = read_raw_bids(bids_path)
# <Info | 11 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F7, F3, Fz, F4, F8, FC5, FC1, FC2, FC6, T7, C3, Cz, ...
#  chs: 63 EEG, 1 EOG
#  custom_ref_applied: False
#  description: Anonymized using a time shift to preserve age at acquisition
#  experimenter: mne_anonymize
#  highpass: 0.0 Hz
#  line_freq: 50.0
#  lowpass: 250.0 Hz
#  meas_date: 1800-12-31 04:11:37 UTC
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
#  subject_info: <subject_info | his_id: sub-02, birthday: 1776-12-30>
# >

# %%
raw.get_data().shape
# Out:
# (64, 258030)

# %%
plt.plot(raw[10,:100][0].T)

# %%
raw.plot(start=0, duration=1);
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ## Filtering

# %%
pz_ch = raw.copy().pick(["Cz"])
plt.plot(pz_ch.get_data()[0, :])
pz_ch.compute_psd().plot();
# Out:
# Effective window size : 4.096 (s)
# Plotting power spectral density (dB=True).
# Need more than one channel to make topography for eeg. Disabling interactivity.
# /var/folders/bb/xxm_9vsj1w9c1jg8lvn4kll00000gn/T/ipykernel_61359/2820817313.py:3: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   pz_ch.compute_psd().plot();
# /Users/jan/miniforge3/envs/eeg/lib/python3.12/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# # Remove 50 Hz line noise and also 150 Hz noise

# %%
raw_filtered = raw.load_data().copy().notch_filter(freqs=[50, 150])
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 3301 samples (6.602 s)

# %% [markdown]
# # Apply a bandpass filter

# %%
raw_filtered = raw_filtered.load_data().copy().filter(0.1, 125)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 1.2e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 125.00 Hz
# - Upper transition bandwidth: 31.25 Hz (-6 dB cutoff frequency: 140.62 Hz)
# - Filter length: 16501 samples (33.002 s)

# %%
pz_ch = raw_filtered.copy().pick(["Cz"])
plt.plot(pz_ch.get_data()[0, :])
pz_ch.compute_psd().plot();
# Out:
# Effective window size : 4.096 (s)
# Plotting power spectral density (dB=True).
# Need more than one channel to make topography for eeg. Disabling interactivity.
# /var/folders/bb/xxm_9vsj1w9c1jg8lvn4kll00000gn/T/ipykernel_61359/2250263538.py:3: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   pz_ch.compute_psd().plot();
# /Users/jan/miniforge3/envs/eeg/lib/python3.12/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
raw_filtered.plot(start=0, duration=1);
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# # Resample to 250 Hz

# %%
raw_filtered_resampled = raw_filtered.copy().resample(250)

# %% [markdown]
# # Referencing

# %%
raw_filtered_resampled_referenced = raw_filtered_resampled.set_eeg_reference('average')
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.

# %% [markdown]
# # Epoching

# %%
evts, evts_dict = mne.events_from_annotations(raw)
evts, evts_dict
# Out:
# Used Annotations descriptions: [np.str_('block:end;currentBlockNr:1;condition:vibro;training:false'), np.str_('block:start;currentBlockNr:1;condition:vibro;training:false'), np.str_('box:spawned;condition:vibro;trial_nr:100;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.674886'), np.str_('box:spawned;condition:vibro;trial_nr:10;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.224597'), np.str_('box:spawned;condition:vibro;trial_nr:11;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.552389'), np.str_('box:spawned;condition:vibro;trial_nr:12;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.997462'), np.str_('box:spawned;condition:vibro;trial_nr:13;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.716086'), np.str_('box:spawned;condition:vibro;trial_nr:14;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.209728'), np.str_('box:spawned;condition:vibro;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.27803'), np.str_('box:spawned;condition:vibro;trial_nr:16;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.249389'), np.str_('box:spawned;condition:vibro;trial_nr:17;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.483754'), np.str_('box:spawned;condition:vibro;trial_nr:18;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613091'), np.str_('box:spawned;condition:vibro;trial_nr:19;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.116811'), np.str_('box:spawned;condition:vibro;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.724326'), np.str_('box:spawned;condition:vibro;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000348'), np.str_('box:spawned;condition:vibro;trial_nr:21;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.702756'), np.str_('box:spawned;condition:vibro;trial_nr:22;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.559482'), np.str_('box:spawned;condition:vibro;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.847122'), np.str_('box:spawned;condition:vibro;trial_nr:24;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.120737'), np.str_('box:spawned;condition:vibro;trial_nr:25;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.721076'), np.str_('box:spawned;condition:vibro;trial_nr:26;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.507959'), np.str_('box:spawned;condition:vibro;trial_nr:27;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.806397'), np.str_('box:spawned;condition:vibro;trial_nr:28;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.893319'), np.str_('box:spawned;condition:vibro;trial_nr:29;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.88759'), np.str_('box:spawned;condition:vibro;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.532965'), np.str_('box:spawned;condition:vibro;trial_nr:30;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.950921'), np.str_('box:spawned;condition:vibro;trial_nr:31;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.933848'), np.str_('box:spawned;condition:vibro;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.233932'), np.str_('box:spawned;condition:vibro;trial_nr:33;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.936249'), np.str_('box:spawned;condition:vibro;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.323753'), np.str_('box:spawned;condition:v ...
# (array([[    93,      0,  10002],
#         [  1204,      0,  10014],
#         [  1678,      0,  10293],
#         ...,
#         [247779,      0,  10305],
#         [253459,      0,  10306],
#         [254457,      0,  10001]], shape=(505, 3)),
#  {np.str_('block:end;currentBlockNr:1;condition:vibro;training:false'): 10001,
#   np.str_('block:start;currentBlockNr:1;condition:vibro;training:false'): 10002,
#   np.str_('box:spawned;condition:vibro;trial_nr:100;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.674886'): 10003,
#   np.str_('box:spawned;condition:vibro;trial_nr:10;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.224597'): 10004,
#   np.str_('box:spawned;condition:vibro;trial_nr:11;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.552389'): 10005,
#   np.str_('box:spawned;condition:vibro;trial_nr:12;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.997462'): 10006,
#   np.str_('box:spawned;condition:vibro;trial_nr:13;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.716086'): 10007,
#   np.str_('box:spawned;condition:vibro;trial_nr:14;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.209728'): 10008,
#   np.str_('box:spawned;condition:vibro;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.27803'): 10009,
#   np.str_('box:spawned;condition:vibro;trial_nr:16;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.249389'): 10010,
#   np.str_('box:spawned;condition:vibro;trial_nr:17;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.483754'): 10011,
#   np.str_('box:spawned;condition:vibro;trial_nr:18;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613091'): 10012,
#   np.str_('box:spawned;condition:vibro;trial_nr:19;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.116811'): 10013,
#   np.str_('box:spawned;condition:vibro;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.724326'): 10014,
#   np.str_('box:spawned;condition:vibro;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000348'): 10015,
#   np.str_('box:spawned;condition:vibro;trial_nr:21;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.702756'): 10016,
#   np.str_('box:spawned;condition:vibro;trial_nr:22;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.559482'): 10017,
#   np.str_('box:spawned;condition:vibro;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.847122'): 10018,
#   np.str_('box:spawned;condition:vibro;trial_nr:24;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.120737'): 10019,
#   np.str_('box:spawned;condition:vibro;trial_nr:25;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.721076'): 10020,
#   np.str_('box:spawned;condition:vibro;trial_nr:26;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.507959'): 10021,
#   np.str_('box:spawned;condition:vibro;trial_nr:27;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.806397'): 10022,
#   np.str_('box:spawned;condition:vibro;trial_nr:28;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.893319'): 10023,
#   np.str_('box:spawned;condition:vibro;trial_nr:29;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.88759'): 10024,
#   np.str_('box:spawned;condition:vibro;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.532965'): 10025,
#   np.str_('box:spawned;condition:vibro;trial_nr:30;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.950921'): 10026,
#   np.str_('box:spawned;condition:vibro;trial_nr:31;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.933848'): 10027,
#   np.str_('box:spawned;condition:vibro;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.233932'): 10028,
#   np.str_('box:spawned;condition:vibro;trial_nr:33;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.936249'): 10029,
#   np.str_('box:spawned;condition:vibro;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.323753'): 10030,
#   np.str_('box:spawned;condition:vibro;trial_nr:35;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.684624'): 10031,
#   np.str_('box:spawned;condition:vibro;trial_nr:36;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.996166'): 10032,
#   np.str_('box:spawned;condition:vibro;trial_nr:37;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.481588'): 10033,
#   np.str_('box:spawned;condition:vibro;trial_nr:38;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.665277'): 10034,
#   np.str_('box:spawned;condition:vibro;trial_nr:39;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.331215'): 10035,
#   np.str_('box:spawned;condition:vibro;trial_nr:3;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.163727'): 10036,
#   np.str_('box:spawned;condition:vibro;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.623218'): 10037,
#   np.str_('box:spawned;condition:vibro;trial_nr:41;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.695375'): 10038,
#   np.str_('box:spawned;condition:vibro;trial_nr:42;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.816276'): 10039,
#   np.str_('box:spawned;condition:vibro;trial_nr:43;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.738025'): 10040,
#   np.str_('box:spawned;condition:vibro;trial_nr:44;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.530127'): 10041,
#   np.str_('box:spawned;condition:vibro;trial_nr:45;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.986693'): 10042,
#   np.str_('box:spawned;condition:vibro;trial_nr:46;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.047566'): 10043,
#   np.str_('box:spawned;condition:vibro;trial_nr:47;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.985434'): 10044,
#   np.str_('box:spawned;condition:vibro;trial_nr:48;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.986953'): 10045,
#   np.str_('box:spawned;condition:vibro;trial_nr:49;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.786891'): 10046,
#   np.str_('box:spawned;condition:vibro;trial_nr:4;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.271623'): 10047,
#   np.str_('box:spawned;condition:vibro;trial_nr:50;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.760718'): 10048,
#   np.str_('box:spawned;condition:vibro;trial_nr:51;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.335137'): 10049,
#   np.str_('box:spawned;condition:vibro;trial_nr:52;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.136563'): 10050,
#   np.str_('box:spawned;condition:vibro;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.269381'): 10051,
#   np.str_('box:spawned;condition:vibro;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066743'): 10052,
#   np.str_('box:spawned;condition:vibro;trial_nr:55;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.03162'): 10053,
#   np.str_('box:spawned;condition:vibro;trial_nr:56;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.208763'): 10054,
#   np.str_('box:spawned;condition:vibro;trial_nr:57;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.028133'): 10055,
#   np.str_('box:spawned;condition:vibro;trial_nr:58;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.976429'): 10056,
#   np.str_('box:spawned;condition:vibro;trial_nr:59;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.102674'): 10057,
#   np.str_('box:spawned;condition:vibro;trial_nr:5;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.492364'): 10058,
#   np.str_('box:spawned;condition:vibro;trial_nr:60;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.19088'): 10059,
#   np.str_('box:spawned;condition:vibro;trial_nr:61;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.314504'): 10060,
#   np.str_('box:spawned;condition:vibro;trial_nr:62;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.924306'): 10061,
#   np.str_('box:spawned;condition:vibro;trial_nr:63;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.007245'): 10062,
#   np.str_('box:spawned;condition:vibro;trial_nr:64;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.468874'): 10063,
#   np.str_('box:spawned;condition:vibro;trial_nr:65;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.520457'): 10064,
#   np.str_('box:spawned;condition:vibro;trial_nr:66;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.784391'): 10065,
#   np.str_('box:spawned;condition:vibro;trial_nr:67;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.629771'): 10066,
#   np.str_('box:spawned;condition:vibro;trial_nr:68;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.720699'): 10067,
#   np.str_('box:spawned;condition:vibro;trial_nr:69;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.19266'): 10068,
#   np.str_('box:spawned;condition:vibro;trial_nr:6;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.903313'): 10069,
#   np.str_('box:spawned;condition:vibro;trial_nr:70;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.876759'): 10070,
#   np.str_('box:spawned;condition:vibro;trial_nr:71;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.104989'): 10071,
#   np.str_('box:spawned;condition:vibro;trial_nr:72;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.69837'): 10072,
#   np.str_('box:spawned;condition:vibro;trial_nr:73;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.608706'): 10073,
#   np.str_('box:spawned;condition:vibro;trial_nr:74;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.128853'): 10074,
#   np.str_('box:spawned;condition:vibro;trial_nr:75;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.376033'): 10075,
#   np.str_('box:spawned;condition:vibro;trial_nr:76;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.38101'): 10076,
#   np.str_('box:spawned;condition:vibro;trial_nr:77;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.549836'): 10077,
#   np.str_('box:spawned;condition:vibro;trial_nr:78;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.269108'): 10078,
#   np.str_('box:spawned;condition:vibro;trial_nr:79;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.148228'): 10079,
#   np.str_('box:spawned;condition:vibro;trial_nr:7;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.242406'): 10080,
#   np.str_('box:spawned;condition:vibro;trial_nr:80;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.52882'): 10081,
#   np.str_('box:spawned;condition:vibro;trial_nr:81;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.96351'): 10082,
#   np.str_('box:spawned;condition:vibro;trial_nr:82;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.536263'): 10083,
#   np.str_('box:spawned;condition:vibro;trial_nr:83;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.356781'): 10084,
#   np.str_('box:spawned;condition:vibro;trial_nr:84;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.180762'): 10085,
#   np.str_('box:spawned;condition:vibro;trial_nr:85;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.633389'): 10086,
#   np.str_('box:spawned;condition:vibro;trial_nr:86;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.859517'): 10087,
#   np.str_('box:spawned;condition:vibro;trial_nr:87;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.504827'): 10088,
#   np.str_('box:spawned;condition:vibro;trial_nr:88;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.170963'): 10089,
#   np.str_('box:spawned;condition:vibro;trial_nr:89;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.033286'): 10090,
#   np.str_('box:spawned;condition:vibro;trial_nr:8;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.035006'): 10091,
#   np.str_('box:spawned;condition:vibro;trial_nr:90;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.35266'): 10092,
#   np.str_('box:spawned;condition:vibro;trial_nr:91;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.930322'): 10093,
#   np.str_('box:spawned;condition:vibro;trial_nr:92;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.4777'): 10094,
#   np.str_('box:spawned;condition:vibro;trial_nr:93;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.488142'): 10095,
#   np.str_('box:spawned;condition:vibro;trial_nr:94;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.496411'): 10096,
#   np.str_('box:spawned;condition:vibro;trial_nr:95;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.232769'): 10097,
#   np.str_('box:spawned;condition:vibro;trial_nr:96;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.521285'): 10098,
#   np.str_('box:spawned;condition:vibro;trial_nr:97;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.144453'): 10099,
#   np.str_('box:spawned;condition:vibro;trial_nr:98;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.206501'): 10100,
#   np.str_('box:spawned;condition:vibro;trial_nr:99;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.929609'): 10101,
#   np.str_('box:spawned;condition:vibro;trial_nr:9;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.195461'): 10102,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.3457398;trial_nr:64;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.468874;emsCurrent:7;emsWidth:200;pulseCount:12'): 10103,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.4467683;trial_nr:17;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.483754;emsCurrent:7;emsWidth:200;pulseCount:12'): 10104,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.4476047;trial_nr:47;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.985434;emsCurrent:7;emsWidth:200;pulseCount:12'): 10105,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.4478106;trial_nr:60;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.19088;emsCurrent:7;emsWidth:200;pulseCount:12'): 10106,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.469646;trial_nr:29;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.88759;emsCurrent:7;emsWidth:200;pulseCount:12'): 10107,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5025349;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000348;emsCurrent:7;emsWidth:200;pulseCount:12'): 10108,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5039439;trial_nr:51;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.335137;emsCurrent:7;emsWidth:200;pulseCount:12'): 10109,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5139022;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.623218;emsCurrent:7;emsWidth:200;pulseCount:12'): 10110,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5192366;trial_nr:57;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.028133;emsCurrent:7;emsWidth:200;pulseCount:12'): 10111,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5249372;trial_nr:63;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.007245;emsCurrent:7;emsWidth:200;pulseCount:12'): 10112,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5366597;trial_nr:58;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.976429;emsCurrent:7;emsWidth:200;pulseCount:12'): 10113,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5366936;trial_nr:77;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.549836;emsCurrent:7;emsWidth:200;pulseCount:12'): 10114,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5467167;trial_nr:24;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.120737;emsCurrent:7;emsWidth:200;pulseCount:12'): 10115,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5470858;trial_nr:89;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.033286;emsCurrent:7;emsWidth:200;pulseCount:12'): 10116,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5475852;trial_nr:11;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.552389;emsCurrent:7;emsWidth:200;pulseCount:12'): 10117,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5591486;trial_nr:21;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.702756;emsCurrent:7;emsWidth:200;pulseCount:12'): 10118,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.55933;trial_nr:49;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.786891;emsCurrent:7;emsWidth:200;pulseCount:12'): 10119,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5686879;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.269381;emsCurrent:7;emsWidth:200;pulseCount:12'): 10120,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.569356;trial_nr:9;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.195461;emsCurrent:7;emsWidth:200;pulseCount:12'): 10121,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5696158;trial_nr:100;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.674886;emsCurrent:7;emsWidth:200;pulseCount:12'): 10122,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5696473;trial_nr:69;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.19266;emsCurrent:7;emsWidth:200;pulseCount:12'): 10123,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5801787;trial_nr:71;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.104989;emsCurrent:7;emsWidth:200;pulseCount:12'): 10124,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5809379;trial_nr:4;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.271623;emsCurrent:7;emsWidth:200;pulseCount:12'): 10125,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5814397;trial_nr:44;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.530127;emsCurrent:7;emsWidth:200;pulseCount:12'): 10126,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5908713;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.847122;emsCurrent:7;emsWidth:200;pulseCount:12'): 10127,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.592675;trial_nr:31;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.933848;emsCurrent:7;emsWidth:200;pulseCount:12'): 10128,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.5982008;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.27803;emsCurrent:7;emsWidth:200;pulseCount:12'): 10129,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6023388;trial_nr:46;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.047566;emsCurrent:7;emsWidth:200;pulseCount:12'): 10130,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6032872;trial_nr:52;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.136563;emsCurrent:7;emsWidth:200;pulseCount:12'): 10131,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6145039;trial_nr:84;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.180762;emsCurrent:7;emsWidth:200;pulseCount:12'): 10132,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6153536;trial_nr:98;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.206501;emsCurrent:7;emsWidth:200;pulseCount:12'): 10133,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6245391;trial_nr:28;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.893319;emsCurrent:7;emsWidth:200;pulseCount:12'): 10134,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6253939;trial_nr:56;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.208763;emsCurrent:7;emsWidth:200;pulseCount:12'): 10135,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.636431;trial_nr:48;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.986953;emsCurrent:7;emsWidth:200;pulseCount:12'): 10136,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6365333;trial_nr:37;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.481588;emsCurrent:7;emsWidth:200;pulseCount:12'): 10137,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6368697;trial_nr:91;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.930322;emsCurrent:7;emsWidth:200;pulseCount:12'): 10138,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6472778;trial_nr:19;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.116811;emsCurrent:7;emsWidth:200;pulseCount:12'): 10139,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6477416;trial_nr:42;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.816276;emsCurrent:7;emsWidth:200;pulseCount:12'): 10140,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6478026;trial_nr:22;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.559482;emsCurrent:7;emsWidth:200;pulseCount:12'): 10141,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6481745;trial_nr:80;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.52882;emsCurrent:7;emsWidth:200;pulseCount:12'): 10142,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6487057;trial_nr:26;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.507959;emsCurrent:7;emsWidth:200;pulseCount:12'): 10143,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6592135;trial_nr:79;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.148228;emsCurrent:7;emsWidth:200;pulseCount:12'): 10144,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6696677;trial_nr:50;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.760718;emsCurrent:7;emsWidth:200;pulseCount:12'): 10145,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.670609;trial_nr:88;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.170963;emsCurrent:7;emsWidth:200;pulseCount:12'): 10146,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6818299;trial_nr:90;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.35266;emsCurrent:7;emsWidth:200;pulseCount:12'): 10147,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6822495;trial_nr:61;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.314504;emsCurrent:7;emsWidth:200;pulseCount:12'): 10148,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6833446;trial_nr:81;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.96351;emsCurrent:7;emsWidth:200;pulseCount:12'): 10149,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.692503;trial_nr:62;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.924306;emsCurrent:7;emsWidth:200;pulseCount:12'): 10150,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6925297;trial_nr:83;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.356781;emsCurrent:7;emsWidth:200;pulseCount:12'): 10151,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6925752;trial_nr:96;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.521285;emsCurrent:7;emsWidth:200;pulseCount:12'): 10152,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6927078;trial_nr:65;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.520457;emsCurrent:7;emsWidth:200;pulseCount:12'): 10153,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.6927207;trial_nr:68;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.720699;emsCurrent:7;emsWidth:200;pulseCount:12'): 10154,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7038679;trial_nr:7;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.242406;emsCurrent:7;emsWidth:200;pulseCount:12'): 10155,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7042017;trial_nr:97;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.144453;emsCurrent:7;emsWidth:200;pulseCount:12'): 10156,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7043619;trial_nr:33;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.936249;emsCurrent:7;emsWidth:200;pulseCount:12'): 10157,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7147152;trial_nr:35;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.684624;emsCurrent:7;emsWidth:200;pulseCount:12'): 10158,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7256465;trial_nr:45;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.986693;emsCurrent:7;emsWidth:200;pulseCount:12'): 10159,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7259851;trial_nr:13;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.716086;emsCurrent:7;emsWidth:200;pulseCount:12'): 10160,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7265971;trial_nr:25;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.721076;emsCurrent:7;emsWidth:200;pulseCount:12'): 10161,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7266459;trial_nr:14;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.209728;emsCurrent:7;emsWidth:200;pulseCount:12'): 10162,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7271769;trial_nr:43;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.738025;emsCurrent:7;emsWidth:200;pulseCount:12'): 10163,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7363055;trial_nr:78;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.269108;emsCurrent:7;emsWidth:200;pulseCount:12'): 10164,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.738277;trial_nr:59;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.102674;emsCurrent:7;emsWidth:200;pulseCount:12'): 10165,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.747894;trial_nr:94;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.496411;emsCurrent:7;emsWidth:200;pulseCount:12'): 10166,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7605157;trial_nr:99;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.929609;emsCurrent:7;emsWidth:200;pulseCount:12'): 10167,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7709293;trial_nr:66;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.784391;emsCurrent:7;emsWidth:200;pulseCount:12'): 10168,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7818482;trial_nr:36;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.996166;emsCurrent:7;emsWidth:200;pulseCount:12'): 10169,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.792814;trial_nr:16;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.249389;emsCurrent:7;emsWidth:200;pulseCount:12'): 10170,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7935328;trial_nr:27;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.806397;emsCurrent:7;emsWidth:200;pulseCount:12'): 10171,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7935419;trial_nr:67;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.629771;emsCurrent:7;emsWidth:200;pulseCount:12'): 10172,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.7936659;trial_nr:87;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.504827;emsCurrent:7;emsWidth:200;pulseCount:12'): 10173,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8043175;trial_nr:86;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.859517;emsCurrent:7;emsWidth:200;pulseCount:12'): 10174,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.804601;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.323753;emsCurrent:7;emsWidth:200;pulseCount:12'): 10175,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8259971;trial_nr:10;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.224597;emsCurrent:7;emsWidth:200;pulseCount:12'): 10176,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8261425;trial_nr:93;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.488142;emsCurrent:7;emsWidth:200;pulseCount:12'): 10177,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8267851;trial_nr:6;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.903313;emsCurrent:7;emsWidth:200;pulseCount:12'): 10178,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8270168;trial_nr:95;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.232769;emsCurrent:7;emsWidth:200;pulseCount:12'): 10179,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8371756;trial_nr:70;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.876759;emsCurrent:7;emsWidth:200;pulseCount:12'): 10180,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8373113;trial_nr:76;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.38101;emsCurrent:7;emsWidth:200;pulseCount:12'): 10181,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8381412;trial_nr:39;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.331215;emsCurrent:7;emsWidth:200;pulseCount:12'): 10182,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8488309;trial_nr:82;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.536263;emsCurrent:7;emsWidth:200;pulseCount:12'): 10183,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8594539;trial_nr:92;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.4777;emsCurrent:7;emsWidth:200;pulseCount:12'): 10184,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8701689;trial_nr:30;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.950921;emsCurrent:7;emsWidth:200;pulseCount:12'): 10185,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8711882;trial_nr:12;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.997462;emsCurrent:7;emsWidth:200;pulseCount:12'): 10186,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8831367;trial_nr:72;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.69837;emsCurrent:7;emsWidth:200;pulseCount:12'): 10187,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8934343;trial_nr:73;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.608706;emsCurrent:7;emsWidth:200;pulseCount:12'): 10188,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8935871;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.233932;emsCurrent:7;emsWidth:200;pulseCount:12'): 10189,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.8948512;trial_nr:3;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.163727;emsCurrent:7;emsWidth:200;pulseCount:12'): 10190,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9159367;trial_nr:74;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.128853;emsCurrent:7;emsWidth:200;pulseCount:12'): 10191,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9386265;trial_nr:5;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.492364;emsCurrent:7;emsWidth:200;pulseCount:12'): 10192,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9386394;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.724326;emsCurrent:7;emsWidth:200;pulseCount:12'): 10193,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9492652;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066743;emsCurrent:7;emsWidth:200;pulseCount:12'): 10194,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9723489;trial_nr:18;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613091;emsCurrent:7;emsWidth:200;pulseCount:12'): 10195,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:0.9834971;trial_nr:75;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.376033;emsCurrent:7;emsWidth:200;pulseCount:12'): 10196,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:1.037156;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.532965;emsCurrent:7;emsWidth:200;pulseCount:12'): 10197,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:1.083776;trial_nr:85;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.633389;emsCurrent:7;emsWidth:200;pulseCount:12'): 10198,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:1.150741;trial_nr:8;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.035006;emsCurrent:7;emsWidth:200;pulseCount:12'): 10199,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:1.161838;trial_nr:38;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.665277;emsCurrent:7;emsWidth:200;pulseCount:12'): 10200,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:1.172889;trial_nr:41;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.695375;emsCurrent:7;emsWidth:200;pulseCount:12'): 10201,
#   np.str_('box:touched;condition:vibro;emsFeedback:on;reaction_time:1.208562;trial_nr:55;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.03162;emsCurrent:7;emsWidth:200;pulseCount:12'): 10202,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.3457398;trial_nr:64;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.468874;vibro_duration:0.1'): 10203,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.4467683;trial_nr:17;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.483754;vibro_duration:0.1'): 10204,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.4476047;trial_nr:47;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.985434;vibro_duration:0.1'): 10205,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.4478106;trial_nr:60;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.19088;vibro_duration:0.1'): 10206,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.469646;trial_nr:29;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.88759;vibro_duration:0.1'): 10207,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5025349;trial_nr:20;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.000348;vibro_duration:0.1'): 10208,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5039439;trial_nr:51;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.335137;vibro_duration:0.1'): 10209,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5139022;trial_nr:40;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.623218;vibro_duration:0.1'): 10210,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5192366;trial_nr:57;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.028133;vibro_duration:0.1'): 10211,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5249372;trial_nr:63;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.007245;vibro_duration:0.1'): 10212,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5366597;trial_nr:58;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.976429;vibro_duration:0.1'): 10213,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5366936;trial_nr:77;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.549836;vibro_duration:0.1'): 10214,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5467167;trial_nr:24;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.120737;vibro_duration:0.1'): 10215,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5470858;trial_nr:89;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.033286;vibro_duration:0.1'): 10216,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5475852;trial_nr:11;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.552389;vibro_duration:0.1'): 10217,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5591486;trial_nr:21;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.702756;vibro_duration:0.1'): 10218,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.55933;trial_nr:49;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.786891;vibro_duration:0.1'): 10219,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5686879;trial_nr:53;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.269381;vibro_duration:0.1'): 10220,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.569356;trial_nr:9;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.195461;vibro_duration:0.1'): 10221,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5696158;trial_nr:100;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.674886;vibro_duration:0.1'): 10222,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5696473;trial_nr:69;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.19266;vibro_duration:0.1'): 10223,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5801787;trial_nr:71;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.104989;vibro_duration:0.1'): 10224,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5809379;trial_nr:4;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.271623;vibro_duration:0.1'): 10225,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5814397;trial_nr:44;normal_or_conflict:conflict;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.530127;vibro_duration:0.1'): 10226,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5908713;trial_nr:23;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.847122;vibro_duration:0.1'): 10227,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.592675;trial_nr:31;normal_or_conflict:conflict;cube:CubeRight (UnityEngine.GameObject);isiTime:1.933848;vibro_duration:0.1'): 10228,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.5982008;trial_nr:15;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.27803;vibro_duration:0.1'): 10229,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6023388;trial_nr:46;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.047566;vibro_duration:0.1'): 10230,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6032872;trial_nr:52;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.136563;vibro_duration:0.1'): 10231,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6145039;trial_nr:84;normal_or_conflict:conflict;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.180762;vibro_duration:0.1'): 10232,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6153536;trial_nr:98;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.206501;vibro_duration:0.1'): 10233,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6245391;trial_nr:28;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.893319;vibro_duration:0.1'): 10234,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.6253939;trial_nr:56;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.208763;vibro_duration:0.1'): 10235,
# ...
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7265971;trial_nr:25;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.721076;vibro_duration:0.1'): 10261,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7266459;trial_nr:14;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.209728;vibro_duration:0.1'): 10262,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7271769;trial_nr:43;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.738025;vibro_duration:0.1'): 10263,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7363055;trial_nr:78;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.269108;vibro_duration:0.1'): 10264,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.738277;trial_nr:59;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.102674;vibro_duration:0.1'): 10265,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.747894;trial_nr:94;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.496411;vibro_duration:0.1'): 10266,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7605157;trial_nr:99;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.929609;vibro_duration:0.1'): 10267,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7709293;trial_nr:66;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.784391;vibro_duration:0.1'): 10268,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7818482;trial_nr:36;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.996166;vibro_duration:0.1'): 10269,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.792814;trial_nr:16;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.249389;vibro_duration:0.1'): 10270,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7935328;trial_nr:27;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.806397;vibro_duration:0.1'): 10271,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7935419;trial_nr:67;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.629771;vibro_duration:0.1'): 10272,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.7936659;trial_nr:87;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.504827;vibro_duration:0.1'): 10273,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8043175;trial_nr:86;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.859517;vibro_duration:0.1'): 10274,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.804601;trial_nr:34;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.323753;vibro_duration:0.1'): 10275,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8259971;trial_nr:10;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.224597;vibro_duration:0.1'): 10276,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8261425;trial_nr:93;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.488142;vibro_duration:0.1'): 10277,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8267851;trial_nr:6;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.903313;vibro_duration:0.1'): 10278,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8270168;trial_nr:95;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.232769;vibro_duration:0.1'): 10279,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8371756;trial_nr:70;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.876759;vibro_duration:0.1'): 10280,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8373113;trial_nr:76;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.38101;vibro_duration:0.1'): 10281,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8381412;trial_nr:39;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.331215;vibro_duration:0.1'): 10282,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8488309;trial_nr:82;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.536263;vibro_duration:0.1'): 10283,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8594539;trial_nr:92;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.4777;vibro_duration:0.1'): 10284,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8701689;trial_nr:30;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.950921;vibro_duration:0.1'): 10285,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8711882;trial_nr:12;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.997462;vibro_duration:0.1'): 10286,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8831367;trial_nr:72;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.69837;vibro_duration:0.1'): 10287,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8934343;trial_nr:73;normal_or_conflict:normal;cube:CubeRight (UnityEngine.GameObject);isiTime:1.608706;vibro_duration:0.1'): 10288,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8935871;trial_nr:32;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.233932;vibro_duration:0.1'): 10289,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.8948512;trial_nr:3;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.163727;vibro_duration:0.1'): 10290,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9159367;trial_nr:74;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.128853;vibro_duration:0.1'): 10291,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9386265;trial_nr:5;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.492364;vibro_duration:0.1'): 10292,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9386394;trial_nr:1;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.724326;vibro_duration:0.1'): 10293,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9492652;trial_nr:54;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.066743;vibro_duration:0.1'): 10294,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9723489;trial_nr:18;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.613091;vibro_duration:0.1'): 10295,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:0.9834971;trial_nr:75;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.376033;vibro_duration:0.1'): 10296,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.037156;trial_nr:2;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.532965;vibro_duration:0.1'): 10297,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.083776;trial_nr:85;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.633389;vibro_duration:0.1'): 10298,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.150741;trial_nr:8;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.035006;vibro_duration:0.1'): 10299,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.161838;trial_nr:38;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.665277;vibro_duration:0.1'): 10300,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.172889;trial_nr:41;normal_or_conflict:normal;cube:CubeMiddle (UnityEngine.GameObject);isiTime:1.695375;vibro_duration:0.1'): 10301,
#   np.str_('box:touched;condition:vibro;vibroFeedback:on;reaction_time:1.208562;trial_nr:55;normal_or_conflict:normal;cube:CubeLeft (UnityEngine.GameObject);isiTime:1.03162;vibro_duration:0.1'): 10302,
#   np.str_('ipq_question_nr_1_answer:3'): 10303,
#   np.str_('ipq_question_nr_2_answer:3'): 10304,
#   np.str_('ipq_question_nr_3_answer:4'): 10305,
#   np.str_('ipq_question_nr_4_answer:2'): 10306,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1000612'): 10307,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1001288'): 10308,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1001485'): 10309,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1001541'): 10310,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1002062'): 10311,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1002457'): 10312,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1002524'): 10313,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1002603'): 10314,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1002627'): 10315,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1002651'): 10316,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1003402'): 10317,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.100354'): 10318,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1003603'): 10319,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1003642'): 10320,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1003678'): 10321,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004049'): 10322,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004219'): 10323,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004251'): 10324,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004476'): 10325,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004512'): 10326,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004516'): 10327,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004519'): 10328,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004768'): 10329,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1004986'): 10330,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1005081'): 10331,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1005317'): 10332,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1005393'): 10333,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1005499'): 10334,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1005958'): 10335,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1006001'): 10336,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1006195'): 10337,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1006819'): 10338,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1006902'): 10339,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1006918'): 10340,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.100706'): 10341,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1007099'): 10342,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1007111'): 10343,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1007202'): 10344,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1007372'): 10345,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1007751'): 10346,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008008'): 10347,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008166'): 10348,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008209'): 10349,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008221'): 10350,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.10083'): 10351,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008356'): 10352,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008715'): 10353,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008889'): 10354,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1008893'): 10355,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1009276'): 10356,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1009347'): 10357,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1009865'): 10358,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1010161'): 10359,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.101056'): 10360,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1010627'): 10361,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1010635'): 10362,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1010991'): 10363,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.101109'): 10364,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1011694'): 10365,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1011864'): 10366,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1011911'): 10367,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1011919'): 10368,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1012824'): 10369,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1012843'): 10370,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1012895'): 10371,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1012911'): 10372,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1014491'): 10373,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1017094'): 10374,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1017742'): 10375,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1018667'): 10376,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1021705'): 10377,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1024849'): 10378,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.102524'): 10379,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.102605'): 10380,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1027295'): 10381,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1028626'): 10382,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1030108'): 10383,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.103012'): 10384,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1030159'): 10385,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1032656'): 10386,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1032699'): 10387,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1032936'): 10388,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.103616'): 10389,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1036504'): 10390,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1038886'): 10391,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1039893'): 10392,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1044373'): 10393,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1046183'): 10394,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1067002'): 10395,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1086108'): 10396,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1103214'): 10397,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1107583'): 10398,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1109432'): 10399,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1109582'): 10400,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1109803'): 10401,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1115627'): 10402,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1117282'): 10403,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1129446'): 10404,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1137075'): 10405,
#   np.str_('vibroFeedback:off;vibroFeedbackDuration:0.1148579'): 10406,
#   np.str_('visualFeedback:off'): 10407})

# %%
wanted_keys = [e for e in evts_dict.keys() if "normal_or_conflict:normal" in e and "box:touched" in e]
evts_dict_stim = dict((k, evts_dict[k]) for k in wanted_keys if k in evts_dict)
evts_dict_stim
epochs = mne.Epochs(raw_filtered_resampled_referenced, evts, evts_dict_stim, tmin=-0.1, tmax=1)
epochs = epochs.load_data().shift_time(-0.063)
epochs.average().copy().pick(['Cz']).plot();
# Out:
# Not setting metadata
# 150 matching events found
# Setting baseline interval to [-0.1, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 276 original time points ...
# 68 bad epochs dropped
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
wanted_keys = [e for e in evts_dict.keys() if "normal_or_conflict:conflict" in e and "box:touched" in e]
evts_dict_stim = dict((k, evts_dict[k]) for k in wanted_keys if k in evts_dict)
epochs = mne.Epochs(raw_filtered_resampled_referenced, evts, evts_dict_stim, tmin=-0.1, tmax=1)
epochs = epochs.load_data().shift_time(-0.063)
epochs.average().copy().pick(['Cz']).plot();
# Out:
# Not setting metadata
# 50 matching events found
# Setting baseline interval to [-0.1, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 50 events and 276 original time points ...
# 24 bad epochs dropped
# Need more than one channel to make topography for eeg. Disabling interactivity.
